# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("../Real_estate.csv")

# %% [markdown]
# # DATA EXPLORATION

# %%
n_rows, n_col = df.shape
print(f"rows: {n_rows}, columns: {n_col}")
# Out:
# rows: 414, columns: 8

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.isna().any()
# Out:
# No                                        False
# X1 transaction date                       False
# X2 house age                              False
# X3 distance to the nearest MRT station    False
# X4 number of convenience stores           False
# X5 latitude                               False
# X6 longitude                              False
# Y house price of unit area                False
# dtype: bool

# %% [markdown]
# # DATA VISUALIZATION:

# %% [markdown]
# #### Let's see the distributions

# %%
new_df = df.iloc[:, 2:5]
new_df["Y house price of unit area"] = df["Y house price of unit area"]
new_df.columns
# Out:
# Index(['X2 house age', 'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'Y house price of unit area'],
#       dtype='object')

# %%
for col in new_df.columns[:-1]:    
    sns.displot(new_df, x = col, shrink = .8)
    plt.title("frequency histogram")

# %% [markdown]
# #### Let's analyze the correlations

# %%
for i, col in enumerate(new_df.columns[:-1]):
    sns.regplot(x = col, y = "Y house price of unit area", data = df)
    plt.title("Correlation")
    plt.show()

# %%
corr = new_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_42eda_row0_col0, #T_42eda_row1_col1, #T_42eda_row2_col2, #T_42eda_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_42eda_row0_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_42eda_row0_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_42eda_row0_col3 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_42eda_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_42eda_row1_col2, #T_42eda_row1_col3, #T_42eda_row3_col0, #T_42eda_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_42eda_row2_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_42eda_row2_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_42eda_row2_col3 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_42eda_row3_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# </style>
# <table id="T_42eda_">
#   <thead>
#     <tr>
# ...

# %%
sns.heatmap(corr, cmap= "coolwarm", annot = True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8891a_row0_col0, #T_8891a_row1_col1, #T_8891a_row2_col2, #T_8891a_row3_col3, #T_8891a_row4_col4, #T_8891a_row5_col5, #T_8891a_row6_col6, #T_8891a_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8891a_row0_col1, #T_8891a_row1_col0, #T_8891a_row3_col4, #T_8891a_row3_col5, #T_8891a_row3_col6, #T_8891a_row3_col7, #T_8891a_row6_col3, #T_8891a_row7_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8891a_row0_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_8891a_row0_col3, #T_8891a_row0_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_8891a_row0_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_8891a_row0_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_8891a_row0_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_8891a_row1_col2 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8891a_row1_col3 {
# ...

# %%
sns.heatmap(corr, cmap= "coolwarm", annot = True)
# Out:
# <AxesSubplot:>
